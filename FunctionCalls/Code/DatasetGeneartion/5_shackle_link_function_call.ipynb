# %% [markdown]
# # Drive

# %%
from google.colab import drive

# %%
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# # Dataset without values

# %%
link_design_strings = [
    "Design a 3D model for a leaf spring shackle link with an hole radius of {joint_radius}, length of {length}, and a height of {height}.",
    "Create a 3D model for a mechanical leaf spring shackle link with equal dimensions. Share length of {length}, hole radius of {joint_radius}, and height of {height}.",
    "Seeking a skilled designer to create a 3D printable leaf spring shackle link with an hole radius of {joint_radius}, length of {length}, and a height of {height}.",
    "I want a leaf spring shackle link model with an hole radius of {joint_radius}, length of {length}, and a height of {height}.",
    "I need quickly a leaf spring shackle link model with an hole radius of {joint_radius}, length of {length}, and a height of {height}.",
    "Looking for a 3D printable leaf spring shackle link design with an hole radius of {joint_radius}, length of {length}, and a height of {height}.",
    "Design needed: leaf spring shackle link with an hole radius of {joint_radius}, length of {length}, and height {height}.",
    "Hola , Can you draw a leaf spring shackle link model with an hole radius of {joint_radius}, length of {length}, and a height of {height}.",
    "For my project can you help me draw a spring schakle link with a hole radius of {joint_radius}, length of {length}, and a height of {height}.",
    "Help me drawing a leaf spring shackle link model with an hole radius of {joint_radius}, length of {length}, and a height of {height}.",
    "I need a leaf spring shackle link model with an hole radius of {joint_radius}, length of {length}, and a height of {height}."]

# %%
link_design_strings = [
    "Design a 3D model for a leaf spring shackle link with an hole radius of {joint_radius}, length of {length}, and a height of {height}.",
    "Seeking a skilled designer to create a 3D printable leaf spring shackle link with an hole radius of {joint_radius}, length of {length}, and a height of {height}.",
    "Looking for a CAD expert to craft a leaf spring shackle link model with an hole radius of {joint_radius}, length of {length}, and a height of {height}.",
    "Need a custom-designed leaf spring shackle link model: hole radius {joint_radius}, length of {length}, and height {height}.",
    "Requesting a 3D model for a leaf spring shackle link with an hole radius of {joint_radius}, length of {length}, and a height of {height}.",
    "Seeking a CAD designer proficient in jewelry design to create a leaf spring shackle link model with an hole radius of {joint_radius}, length of {length}, and a height of {height}.",
    "Looking for a 3D printable leaf spring shackle link design with an hole radius of {joint_radius}, length of {length}, and a height of {height}.",
    "Design needed: leaf spring shackle link with an hole radius of {joint_radius}, length of {length}, and height {height}.",
    "Seeking a talented 3D modeler to create a leaf spring shackle link with an hole radius of {joint_radius}, length of {length}, and a height of {height}.",
    "Requesting a CAD design for a leaf spring shackle link with an hole radius of {joint_radius}, length of {length}, and a height of {height}.",
    "With a specific height of {height}, seeking a 3D model for a leaf spring shackle link with an hole radius of {joint_radius} and length of {length}.",
    "Starting with an length of {length}, looking for a leaf spring shackle link design with an hole radius of {joint_radius} and a height of {height}.",
    "Beginning from the hole radius of {joint_radius}, need a leaf spring shackle link model with an length of {length} and a specific height of {height}.",
    "For a unique design, starting with an hole radius of {joint_radius}, seeking a leaf spring shackle link with a height of {height} and an length of {length}.",
    "Beginning with a specific length of {length}, in need of a leaf spring shackle link with an hole radius of {joint_radius} and a height of {height}.",
    "Starting with a designated height of {height}, looking for a leaf spring shackle link design with an length of {length} and an hole radius of {joint_radius}.",
    "Requesting a leaf spring shackle link model that begins with an hole radius of {joint_radius}, with a specific length of {length} and a height of {height}.",
    "Needing a leaf spring shackle link design initiated from an length of {length}, with an hole radius of {joint_radius} and a height of {height}.",
    "Starting the design process from the height of {height}, seeking a leaf spring shackle link with an length of {length} and an hole radius of {joint_radius}.",
    "From a specified hole radius of {joint_radius}, in need of a leaf spring shackle link model with an length of {length} and a distinct height of {height}.",
    "Initiating the design process from a designated hole radius of {joint_radius}, seeking a leaf spring shackle link with a specific height of {height} and an length of {length}.",
    "Starting with a precise height of {height}, in need of a leaf spring shackle link design with an hole radius of {joint_radius} and an length of {length}.",
    "With a specified length of {length}, seeking a leaf spring shackle link model that encompasses an hole radius of {joint_radius} and a height of {height}.",
    "From a particular height of {height}, needing a leaf spring shackle link design with an length of {length} and an hole radius of {joint_radius}.",
    "Starting from a designated length of {length}, seeking a leaf spring shackle link with an hole radius of {joint_radius} and a specific height of {height}.",
    "For a unique design, starting with a height of {height}, in need of a leaf spring shackle link with an hole radius of {joint_radius} and an length of {length}.",
    "Commencing the design from an hole radius of {joint_radius}, seeking a leaf spring shackle link with a specific length of {length} and a height of {height}.",
    "Beginning the design process with an length of {length}, in need of a leaf spring shackle link model with an hole radius of {joint_radius} and a designated height of {height}.",
    "With a specific hole radius of {joint_radius}, seeking a leaf spring shackle link design that encompasses an length of {length} and a height of {height}.",
    "Initiating the specifications with a height of {height}, in need of a leaf spring shackle link with an hole radius of {joint_radius} and an length of {length}.",
    "Seeking a leaf spring shackle link design where the sum of length {length}, hole radius {joint_radius}, and height {height} create a balanced and elegant composition.",
    "Looking for a leaf spring shackle link model with the sum of length {length}, hole radius {joint_radius}, and height {height} defining its overall aesthetic appeal.",
    "Requesting a leaf spring shackle link design where the sum of length {length}, hole radius {joint_radius}, and height {height} harmoniously contribute to its structural integrity.",
    "Seeking a creative approach to leaf spring shackle link design where the combined values of length {length}, hole radius {joint_radius}, and height {height} evoke a distinctive style.",
    "Looking for a leaf spring shackle link model that emphasizes the sum of length {length}, hole radius {joint_radius}, and height {height} as a key design element.",
    "Requesting a leaf spring shackle link design where the total of length {length}, hole radius {joint_radius}, and height {height} is integral to its visual and tactile appeal.",
    "Seeking a leaf spring shackle link model where the combined values of length {length}, hole radius {joint_radius}, and height {height} create a unique and memorable design.",
    "Looking for a design exploration where the sum of length {length}, hole radius {joint_radius}, and height {height} influences the overall leaf spring shackle link aesthetics.",
    "Requesting a leaf spring shackle link design that showcases a creative interplay among length {length}, hole radius {joint_radius}, and height {height} to create a captivating piece.",
    "Seeking a designer to craft a leaf spring shackle link model where the collective values of length {length}, hole radius {joint_radius}, and height {height} define its character and appeal.",
    "Requesting a leaf spring shackle link design that creatively combines length {length}, hole radius {joint_radius}, and height {height} to reflect personalized elegance and style.",
    "Seeking a leaf spring shackle link model where the sum of length {length}, hole radius {joint_radius}, and height {height} crafts a harmonious and visually striking composition.",
    "Looking for a leaf spring shackle link design where the interplay of length {length}, hole radius {joint_radius}, and height {height} creates a seamless and refined aesthetic.",
    "In need of a leaf spring shackle link model that optimizes the relationship between length {length}, hole radius {joint_radius}, and height {height} for an exquisite final product.",
    "Seeking a creative exploration of length {length}, hole radius {joint_radius}, and height {height} to redefine conventional leaf spring shackle link design concepts.",
    "Requesting a leaf spring shackle link design where the synergy among length {length}, hole radius {joint_radius}, and height {height} elevates the leaf spring shackle link's uniqueness and allure.",
    "Looking for a leaf spring shackle link model that showcases the perfect balance between length {length}, hole radius {joint_radius}, and height {height} for superior craftsmanship.",
    "Seeking a design that intricately weaves length {length}, hole radius {joint_radius}, and height {height} into an exceptional and bespoke leaf spring shackle link concept.",
    "Requesting a leaf spring shackle link design where the sum of length {length}, hole radius {joint_radius}, and height {height} embodies sophistication and individuality.",
    "In need of a leaf spring shackle link model that accentuates the interwoven elements of length {length}, hole radius {joint_radius}, and height {height} for a captivating design statement.",
    "Would it be possible to create a leaf spring shackle link design incorporating length {length}, hole radius {joint_radius}, and height {height} tailored for a unique touch?",
    "I'm seeking a skilled designer who could craft a leaf spring shackle link model consideleaf spring shackle link length {length}, hole radius {joint_radius}, and height {height} for a personalized design.",
    "Could you assist in creating a leaf spring shackle link design with attention to length {length}, hole radius {joint_radius}, and height {height} for a distinct and elegant style?",
    "Might I request your expertise in designing a leaf spring shackle link model using length {length}, hole radius {joint_radius}, and height {height} for a refined and exquisite look?",
    "I'm hoping to collaborate on a leaf spring shackle link design project focusing on length {length}, hole radius {joint_radius}, and height {height} for a truly bespoke creation.",
    "Would you be able to help in crafting a leaf spring shackle link design featuring length {length}, hole radius {joint_radius}, and height {height} to bleaf spring shackle link a unique vision to life?",
    "I'm in search of a talented designer to assist with a leaf spring shackle link model incorporating length {length}, hole radius {joint_radius}, and height {height} for a personalized touch.",
    "Might I kindly request your expertise in creating a leaf spring shackle link design focusing on length {length}, height {height}, and hole radius {joint_radius} to bleaf spring shackle link a unique vision to life?",
    "I'm hoping to collaborate on a leaf spring shackle link design project consideleaf spring shackle link hole radius {joint_radius}, length {length}, and height {height} for a truly bespoke and elegant creation.",
    "Would you be able to help in designing a leaf spring shackle link featuring height {height}, length {length}, and hole radius {joint_radius} to achieve a distinct and refined appeal?",
    "Could you lend your creative expertise to craft a leaf spring shackle link model with attention to hole radius {joint_radius}, height {height}, and length {length} for a personalized touch?",
    "I'm in search of a talented designer to assist with a leaf spring shackle link design consideleaf spring shackle link an length of {length}, an hole radius of {joint_radius}, and a height of {height} for a bespoke and elegant result.",
    "Might I request your expertise in creating a leaf spring shackle link design with careful consideration of a height of {height}, an length of {length}, and an hole radius of {joint_radius} for a distinctive appeal?",
    "Would it be possible to collaborate on a leaf spring shackle link design project focusing on a height of {height}, an hole radius of {joint_radius}, and an length of {length} for a refined and unique outcome?",
    "Could you assist in crafting a leaf spring shackle link design that balances an length of {length}, an hole radius of {joint_radius}, and a height of {height} to achieve a personalized and elegant style?",
    "I'm hoping to create a leaf spring shackle link model consideleaf spring shackle link an hole radius of {joint_radius}, a height of {height}, and an length of {length} for a truly bespoke and sophisticated design.",
    "Could you help in designing a leaf spring shackle link with an length measure {length}, an hole radius of {joint_radius}, and a height measure {height}? Seeking a unique design perspective.",
    "I'm looking to commission a leaf spring shackle link design with specified dimensions: an hole radius of {joint_radius}, an length of {length}, and a height of {height}. Can you assist?",
    "Seeking expertise in crafting a leaf spring shackle link that embodies precision: an length at {length}, an hole radius at {joint_radius}, and a height of {height}. Your creative input is valued.",
    "In need of a leaf spring shackle link design showcasing craftsmanship: an hole radius at {joint_radius}, an length at {length}, and a height of {height}. Your expertise would be appreciated.",
    "Requesting a personalized leaf spring shackle link model: an length of {length}, an hole radius of {joint_radius}, and a specified height of {height}. Seeking a unique touch.",
    "Exploleaf spring shackle link a leaf spring shackle link design concept that balances dimensions: an hole radius of {joint_radius}, an length at {length}, and a specified height of {height}. Seeking your design expertise.",
    "Looking for a leaf spring shackle link design featuring specific measurements: an length {length}, an hole radius {joint_radius}, and a height {height}. Your creative insights are welcomed.",
    "Seeking a skilled designer to create a leaf spring shackle link model with exact specifications: an hole radius {joint_radius}, an length {length}, and a height {height}. Your attention to detail is valued."
]
link_design_strings += [
    "In need of a leaf spring shackle link design emphasizing precision: an length {length}, an hole radius {joint_radius}, and a height {height}. Your expertise in design is much sought after.",
    "Requesting a unique leaf spring shackle link model: hole radius {joint_radius}, length {length}, and height {height}. Looking forward to your creative input and expertise.",
    "Seeking a leaf spring shackle link design that harmonizes distinctive measurements: an length of {length}, an hole radius of {joint_radius}, and a height measure {height}. Your creative vision is welcomed.",
    "In need of a leaf spring shackle link model showcasing precision: an hole radius set at {joint_radius}, an length at {length}, and a specified height of {height}. Your attention to detail is valued.",
    "Requesting a personalized leaf spring shackle link design: an length of {length}, an hole radius measure {joint_radius}, and a height precisely at {height}. Seeking a unique and refined touch.",
    "Seeking a skilled designer to create a leaf spring shackle link model with exact specifications: an hole radius {joint_radius}, an length {length}, and a height {height}. Your expertise is much appreciated.",
    "Looking for a leaf spring shackle link design featuring specific measurements: an length at {length}, an hole radius at {joint_radius}, and a height precisely set at {height}. Your creative insights are valued.",
    "Requesting a unique leaf spring shackle link model: hole radius {joint_radius}, length {length}, and height {height}. Looking forward to your creative input and expertise.",
    "In need of a leaf spring shackle link design emphasizing precision: an length {length}, an hole radius {joint_radius}, and a height {height}. Your expertise in design is much sought after.",
    "Seeking a leaf spring shackle link design reflecting balance: an hole radius {joint_radius}, an length {length}, and a height {height}. Your creative craftsmanship is valued.",
    "Looking to commission a leaf spring shackle link model with exact specifications: an hole radius at {joint_radius}, an length measure {length}, and a specified height of {height}. Your attention to detail is welcomed.",
    "Requesting a leaf spring shackle link design that balances elegance and precision: an length {length}, an hole radius {joint_radius}, and a height {height}. Your creative expertise is welcomed.",
    "Seeking a leaf spring shackle link design expert to create a masterpiece with an hole radius of {joint_radius}, an length of {length}, and a meticulous height of {height}. Your creative touch is valued.",
    "In need of a leaf spring shackle link model that perfectly balances specifications: an hole radius {joint_radius}, an length {length}, and a carefully measured height of {height}. Your attention to detail is appreciated.",
    "Requesting a personalized leaf spring shackle link design: an length {length}, an hole radius {joint_radius}, and a specific height of {height}. Seeking a design that reflects individual elegance.",
    "Seeking a skilled designer to craft a leaf spring shackle link model: an hole radius {joint_radius}, an length {length}, and a precise height {height}. Your expertise in design is much welcomed.",
    "Looking to commission a leaf spring shackle link model reflecting exact measurements: an length at {length}, an hole radius {joint_radius}, and a specified height of {height}. Your creative insights are valued.",
    "Requesting a unique leaf spring shackle link design: hole radius {joint_radius}, length {length}, and height {height}. Looking forward to your artistic interpretation and expertise.",
    "In need of a leaf spring shackle link design emphasizing precision and elegance: an length {length}, an hole radius {joint_radius}, and a carefully determined height {height}. Your creative craftsmanship is sought after.",
    "Seeking a leaf spring shackle link model reflecting balance and sophistication: an hole radius {joint_radius}, an length {length}, and a carefully defined height {height}. Your creative vision is appreciated.",
    "Looking for a leaf spring shackle link design expert to bleaf spring shackle link specifications to life: an hole radius at {joint_radius}, an length measure {length}, and a specified height of {height}. Your attention to detail is welcomed.",
    "Requesting a leaf spring shackle link design that harmonizes dimensions: an length of {length}, an hole radius at {joint_radius}, and a height carefully set at {height}. Your artistic expertise is much anticipated.",
    "Please craft me a 3D leaf spring shackle link with an hole radius of {joint_radius}, an length of {length}, and a height of {height}.",
    "Design a mechanical leaf spring shackle link with an hole radius of {joint_radius}, an length of {length}, and a height of {height}.",
    "Create a 3D model for a custom leaf spring shackle link with an hole radius of {joint_radius}, an length of {length}, and a height of {height}.",
    "Craft a precision mechanical leaf spring shackle link with an hole radius of {joint_radius}, an length of {length}, and a height of {height} for optimal functionality.",
    "Design a mechanical leaf spring shackle link with intricate gears. Specify the length of {length}, hole radius of {joint_radius}, and height of {height} for a seamless operation.",
    "Create a 3D model for a mechanical leaf spring shackle link with precise dimensions for a sleek and efficient design. Specify the length of {length}, hole radius of {joint_radius}, and height of {height}.",
    "Develop a detailed blueprint for a mechanical leaf spring shackle link, including the length of {length}, hole radius of {joint_radius}, and height of {height} for engineeleaf spring shackle link precision.",
    "Craft a mechanical leaf spring shackle link with hidden compartments and moving parts. Provide the length of {length}, hole radius of {joint_radius}, and height of {height} for a sophisticated touch.",
    "Design a high-precision mechanical leaf spring shackle link with specified length {length}, hole radius {joint_radius}, and height {height} for optimal performance.",
    "Create a customizable mechanical leaf spring shackle link with placeholders for length {length} , hole radius {joint_radius} , and height {height}, allowing for personalized adjustments.",
    "Develop a mechanical leaf spring shackle link prototype with specific dimensions, including length {length} , hole radius {joint_radius} , and height {height}, for testing and refinement."
]
link_design_strings += [
    "Craft an innovative mechanical leaf spring shackle link with an length of {length}, an hole radius of {joint_radius}, and a height of {height} designed for both style and functionality.",
    "Design a mechanical leaf spring shackle link with modular components. Specify the length of {length}, hole radius of {joint_radius}, and height of {height} for easy customization.",
    "Create a detailed 3D model for a mechanical leaf spring shackle link with intricate mechanisms. Specify the length of {length}, hole radius of {joint_radius}, and height of {height} for accurate representation.",
    "Develop a mechanical leaf spring shackle link with moving cogs and gears. Provide the length of {length}, hole radius of {joint_radius}, and height of {height} for a captivating design.",
    "Design a precise mechanical leaf spring shackle link with exact measurements for the length of {length}, hole radius of {joint_radius}, and height of {height}, ensuleaf spring shackle link engineeleaf spring shackle link accuracy.",
    "Craft a mechanical leaf spring shackle link with a minimalist yet functional design. Specify the length of {length}, hole radius of {joint_radius}, and height of {height} for a sleek and modern look.",
    "Create a mechanical leaf spring shackle link inspired by industrial aesthetics. Provide the length of {length}, hole radius of {joint_radius}, and height of {height} for an edgy and stylish design.",
    "Craft a mechanical leaf spring shackle link with a locking mechanism. Specify the length of {length}, hole radius of {joint_radius}, and height of {height} for added security and uniqueness.",
    "Develop a customizable mechanical leaf spring shackle link with placeholders for length {length} , hole radius {joint_radius}, and height {height} , allowing users to personalize the design.",
    "Create a mechanical leaf spring shackle link prototype with precise dimensions, including length {length} , hole radius {joint_radius}, and height {height}, for testing and optimization.",
    "Design an elegant mechanical leaf spring shackle link with intricate details. Specify the length of {length}, hole radius of {joint_radius}, and height of {height} for a sophisticated and functional accessory.",
    "Craft a sleek mechanical leaf spring shackle link with specified length {length} , hole radius {joint_radius}, and height {height} for a minimalist yet stylish design.",
    "Design a mechanical leaf spring shackle link with precise dimensions. Specify the length of {length}, hole radius of {joint_radius}, and height of {height} for a clean and modern look.",
    "Create a 3D model for a mechanical leaf spring shackle link, emphasizing exact length {length} and hole radius {joint_radius}  measurements along with the height of {height} for simplicity and accuracy.",
    "Develop a mechanical leaf spring shackle link with a symmetrical design. Share the length of {length}, hole radius of {joint_radius}, and height of {height} for a balanced and refined accessory.",
    "Craft a mechanical leaf spring shackle link with a geometric twist. Specify the length of {length}, hole radius of {joint_radius}, and height of {height} to create an intriguing and straightforward design.",
    "Design a precision-engineered mechanical leaf spring shackle link with specified dimensions. Specify the length of {length}, hole radius of {joint_radius}, and height of {height} for functionality and simplicity.",
    "Create a customizable mechanical leaf spring shackle link with Specify the length of {length}, hole radius of {joint_radius}, and height of {height} to allow for personalization within defined parameters.",
    "Develop a mechanical leaf spring shackle link prototype with specific dimensions, including length {length} , hole radius {joint_radius} , and height {height}, for testing and refinement.",
    "Craft an innovative mechanical leaf spring shackle link with an length of {length}, an hole radius of {joint_radius}, and a height of {height} designed for both style and functionality.",
    "Design a mechanical leaf spring shackle link with modular components. Specify the length of {length}, hole radius of {joint_radius}, and height of {height} for easy customization.",
    "Create a detailed 3D model for a mechanical leaf spring shackle link with intricate mechanisms. Specify the length of {length}, hole radius of {joint_radius}, and height of {height} for accurate representation.",
    "Develop a mechanical leaf spring shackle link with moving cogs and gears. Provide the length of {length}, hole radius of {joint_radius}, and height of {height} for a captivating design.",
    "Design a precise mechanical leaf spring shackle link with exact measurements for the length of {length}, hole radius of {joint_radius}, and height of {height}, ensuleaf spring shackle link engineeleaf spring shackle link accuracy.",
    "Craft a mechanical leaf spring shackle link with a minimalist yet functional design. Specify the length of {length}, hole radius of {joint_radius}, and height of {height} for a sleek and modern look.",
    "Create a mechanical leaf spring shackle link inspired by industrial aesthetics. Provide the length of {length}, hole radius of {joint_radius}, and height of {height} for an edgy and stylish design.",
    "Craft a mechanical leaf spring shackle link with a locking mechanism. Specify the length of {length}, hole radius of {joint_radius}, and height of {height} for added security and uniqueness.",
    "Develop a customizable mechanical leaf spring shackle link with placeholders for length {length} , hole radius {joint_radius}, and height {height} , allowing users to personalize the design.",
    "Create a mechanical leaf spring shackle link prototype with precise dimensions, including length {length} , hole radius {joint_radius}, and height {height}, for testing and optimization.",
    "Design an elegant mechanical leaf spring shackle link with intricate details. Specify the length of {length}, hole radius of {joint_radius}, and height of {height} for a sophisticated and functional accessory.",
    "Craft a sleek mechanical leaf spring shackle link with specified length {length} , hole radius {joint_radius}, and height {height} for a minimalist yet stylish design.",
    "Design a mechanical leaf spring shackle link with precise dimensions. Specify the length of {length}, hole radius of {joint_radius}, and height of {height} for a clean and modern look.",
    "Create a 3D model for a mechanical leaf spring shackle link, emphasizing exact length {length} and hole radius {joint_radius}  measurements along with the height of {height} for simplicity and accuracy.",
    "Develop a mechanical leaf spring shackle link with a symmetrical design. Share the length of {length}, hole radius of {joint_radius}, and height of {height} for a balanced and refined accessory.",
    "Craft a mechanical leaf spring shackle link with a geometric twist. Specify the length of {length}, hole radius of {joint_radius}, and height of {height} to create an intriguing and straightforward design.",
    "Design a precision-engineered mechanical leaf spring shackle link with specified dimensions. Specify the length of {length}, hole radius of {joint_radius}, and height of {height} for functionality and simplicity.",
    "Create a customizable mechanical leaf spring shackle link with Specify the length of {length}, hole radius of {joint_radius}, and height of {height} to allow for personalization within defined parameters.",
    "Develop a mechanical leaf spring shackle link prototype with specific dimensions, including length {length} , hole radius {joint_radius} , and height {height}, for testing and refinement."
]
link_design_strings += [
    "Design a customizable mechanical leaf spring shackle link with placeholders. Allowing wearers to tailor the design to their preferences by specifying the length of {length}, hole radius of {joint_radius}, and height of {height}.",
    "Craft a mechanical leaf spring shackle link with specific creation of a classic and timeless accessory by specifying the length of {length}, hole radius of {joint_radius}, and height of {height}.",
    "Create a 3D model for a precision-engineered mechanical leaf spring shackle link, specifying the length of {length}, hole radius of {joint_radius}, and height of {height} for a streamlined look.",
    "Design a mechanical leaf spring shackle link with equal length  {length} and hole radius {joint_radius} , and a specified height. Achieve a balanced and harmonious design by specifying the height of {height}.",
    "Craft a customizable mechanical leaf spring shackle link with placeholders. Allow wearers to personalize within defined parameters by specifying the length of {length}, hole radius of {joint_radius}, and height of {height}.",
    "Develop a mechanical leaf spring shackle link with a straightforward design. Create an accessory that combines simplicity with elegance by specifying the length of {length}, hole radius of {joint_radius}, and height of {height}.",
    "Design a precision-engineered mechanical leaf spring shackle link with specified inner and outer dimensions, emphasizing a clean and polished appearance. Specify the length of {length}, hole radius of {joint_radius}, and height of {height}.",
    "Craft a sleek mechanical leaf spring shackle link with specified creation of a minimalist yet stylish design by specifying the length of {length}, hole radius of {joint_radius}, and height of {height}.",
    "Design a mechanical leaf spring shackle link with precise dimensions. Specify the length of {length}, hole radius of {joint_radius}, and height of {height} for a clean and modern look.",
    "Create a 3D model for a mechanical leaf spring shackle link, emphasizing exact length {length} and hole radius {joint_radius}  measurements along with the height of {height} for simplicity and accuracy.",
    "Develop a mechanical leaf spring shackle link with a symmetrical design. Share the length of {length}, hole radius of {joint_radius}, and height of {height} for a balanced and refined accessory.",
    "Craft a mechanical leaf spring shackle link with a geometric twist. Specify the length of {length}, hole radius of {joint_radius}, and height of {height} to create an intriguing and straightforward design.",
    "Design a precision-engineered mechanical leaf spring shackle link with specified dimensions, focusing on functionality and simplicity. Specify the length of {length}, hole radius of {joint_radius}, and height of {height}.",
    "Please craft a sleek mechanical leaf spring shackle link with specific dimensions for a minimalist yet stylish design. Specify the length of {length}, hole radius of {joint_radius}, and height of {height}.",
    "I kindly request a mechanical leaf spring shackle link design with precise dimensions. Could you specify the length of {length}, hole radius of {joint_radius}, and height of {height} for a clean and modern look?",
    "Would you please create a 3D model for a mechanical leaf spring shackle link, emphasizing exact length {length} and hole radius {joint_radius}  measurements along with the height of {height} for simplicity and accuracy?",
    "I would appreciate your expertise in developing a mechanical leaf spring shackle link with a symmetrical design. Could you please share the length of {length}, hole radius of {joint_radius}, and height of {height} for a balanced and refined accessory?",
    "Kindly craft a mechanical leaf spring shackle link with a geometric twist. I'd appreciate it if you could specify the length of {length}, hole radius of {joint_radius}, and height of {height} to create an intriguing and straightforward design.",
    "I kindly request a precision-engineered mechanical leaf spring shackle link with specified dimensions, focusing on functionality and simplicity. Specify the length of {length}, hole radius of {joint_radius}, and height of {height}.",
    "Could you please create a customizable mechanical leaf spring shackle link with placeholders for length {length} , hole radius{joint_radius}, and height {height}? This would allow for personalization within defined parameters.",
    "Your assistance in crafting a mechanical leaf spring shackle link with a clean and polished look would be greatly appreciated. Could you specify the length of {length}, hole radius of {joint_radius}, and height of {height} for an accessory that exudes sophistication?",
    "I would be grateful if you could develop a 3D model for a mechanical leaf spring shackle link with equal length {length} and hole radius {joint_radius} , emphasizing a simple yet timeless design. Specify the height of {height}.",
    "Kindly design a mechanical leaf spring shackle link with specific measurements and height to achieve a harmonious and well-proportioned look. Specify the length of {length}, hole radius of {joint_radius}, and height of {height}.",
    "Your expertise in crafting a precision mechanical leaf spring shackle link with specified specifications for a subtle yet impactful accessory would be greatly valued. Specify the length of {length}, hole radius of {joint_radius}, and height of {height}.",
    "I appreciate your skill in creating a mechanical leaf spring shackle link with concentric circles. Could you please share the length of {length}, hole radius of {joint_radius}, and height of {height} for a visually striking and straightforward design?",
    "Could you please develop a 3D model for a mechanical leaf spring shackle link with equal length {length} and hole radius {joint_radius} dimensions? Specifying the height of {height} for a sleek and uniform appearance would be greatly appreciated.",
    "I kindly request a design for a customizable mechanical leaf spring shackle link with placeholders for some values, allowing wearers to tailor the design to their preferences. Specify the length of {length}, hole radius of {joint_radius}, and height of {height}.",
    "Would you please craft a mechanical leaf spring shackle link with specific length of {length}, hole radius of {joint_radius}, and height of {height} for a classic and timeless accessory?",
    "I appreciate your expertise in developing a 3D model for a precision-engineered mechanical leaf spring shackle link. Focusing on exact length of {length} and hole radius of {joint_radius} dimensions and height of {height} for a streamlined look would be fantastic.",
    "Could you please design a mechanical leaf spring shackle link with equal length of {length} and hole radius of {joint_radius}, and a specified height of {height}, for a balanced and harmonious appearance?",
    "I kindly request a customizable mechanical leaf spring shackle link with placeholders for dimensions, allowing wearers to personalize within defined parameters. Specify the length of {length}, hole radius of {joint_radius}, and height of {height}.",
    "Your assistance in developing a mechanical leaf spring shackle link with a straightforward design is appreciated. Could you please specify the length of {length}, hole radius of {joint_radius}, and height of {height} for an accessory that combines simplicity with elegance?",
    "I would be grateful if you could design a precision-engineered mechanical leaf spring shackle link with specified length of {length}, hole radius of {joint_radius}, and height of {height}, emphasizing a clean and polished appearance.",
    "Please design a sleek mechanical leaf spring shackle link with specific length of {length}, hole radius of {joint_radius}, and height of {height}.",
    "Craft a modern mechanical leaf spring shackle link with precise length of {length}, hole radius of {joint_radius}, and dimensions. Could you provide the details for the height?",
    "Could you create a 3D model for a mechanical leaf spring shackle link with exact length of {length}, hole radius of {joint_radius}, and height of {height}?",
    "Design a symmetrical mechanical leaf spring shackle link, specifying length of {length}, hole radius of {joint_radius}, and height of {height}. Thank you.",
    "Craft a geometric mechanical leaf spring shackle link. Please share the length of {length}, hole radius of {joint_radius}, and height of {height}.",
    "Develop a precision mechanical leaf spring shackle link with placeholders for customization. Specify the length of {length}, hole radius of {joint_radius}, and height of {height}, please.",
    "Design a polished mechanical leaf spring shackle link. Specify length of {length}, hole radius of {joint_radius}, and height of {height} for sophistication.",
    "Create a 3D model for a mechanical leaf spring shackle link with equal dimensions. Share length of {length}, hole radius of {joint_radius}, and height of {height}.",
    "Craft a timeless mechanical leaf spring shackle link. Specify length of {length}, hole radius of {joint_radius}, and height of {height} for balance.",
    "Could you design a streamlined mechanical leaf spring shackle link? Inner radius of {length}, hole radius of {joint_radius}, and height of {height} details appreciated.",
    "Craft a mechanical leaf spring shackle link with dimensions as follows: length of {length}, hole radius of {joint_radius}, and height of {height}.",
    "Design a precise mechanical leaf spring shackle link. Please provide length of {length}, hole radius of {joint_radius}, and height of {height}.",
    "Create a 3D model for a mechanical leaf spring shackle link. Specify exact length {length} and hole radius {joint_radius} measurements along with the height of {height}.",
    "Develop a symmetrical mechanical leaf spring shackle link with the following dimensions: length of {length}, hole radius of {joint_radius}, and height of {height}.",
    "Craft a geometric mechanical leaf spring shackle link. Share specific values for length of {length}, hole radius of {joint_radius}, and height of {height}.",
    "Design a customizable mechanical leaf spring shackle link. Need placeholders for measurements. Specify length of {length}, hole radius of {joint_radius}, and height of {height}.",
    "Create a polished mechanical leaf spring shackle link. Specify length of {length}, hole radius of {joint_radius}, and height of {height} for refinement.",
    "Craft a streamlined mechanical leaf spring shackle link. Provide exact values for length of {length}, hole radius of {joint_radius}, and height of {height}.",
    "Design a balanced mechanical leaf spring shackle link. Please share specific length of {length}, hole radius of {joint_radius}, and height of {height}.",
    "Could you create a mechanical leaf spring shackle link with the following dimensions: length of {length}, hole radius of {joint_radius}, and height of {height}?"
]
link_design_strings += [
    "Mechanical leaf spring shackle link, length of {length}, hole radius of {joint_radius}, and height of {height}?",
    "Craft a leaf spring shackle link with specific length of {length}, hole radius of {joint_radius}, and height of {height}.",
    "3D model: leaf spring shackle link, length {length}, hole radius {joint_radius}, height {height}.",
    "Symmetrical leaf spring shackle link, length {length}, hole radius {joint_radius}, height {height}?",
    "Geometric leaf spring shackle link, length {length}, hole radius {joint_radius}, height {height}.",
    "Polished leaf spring shackle link, length {length}, hole radius {joint_radius}, height {height}.",
    "Streamlined leaf spring shackle link, length {length}, hole radius {joint_radius}, height {height}.",
    "Balanced leaf spring shackle link, length {length}, hole radius {joint_radius}, and height {height}?",
    "Customizable leaf spring shackle link, length {length}, hole radius {joint_radius}, and height {height}?",
    "Specify values: leaf spring shackle link, length {length}, hole radius {joint_radius}, and height {height}.",
    "Hey Tala, got a quick favor – I'm working on a 3D leaf spring shackle link model. Please draw me it with length of {length}, hole radius of {joint_radius}, and height of {height}.",
    "Quick request: I'm onto a 3D leaf spring shackle link project. Draw it with length of {length}, hole radius of {joint_radius}, and height of {height}?",
    "Hey Joud, need your help on a 3D leaf spring shackle link I'm designing. With length of {length}, hole radius of {joint_radius}, and height of {height}?",
    "Craft a mechanical leaf spring shackle link with a harmonious balance in shape. Please share your vision for the hole radius of {joint_radius}, length of {length}, and height of {height}.",
    "Create a leaf spring shackle link with a distinctive silhouette – specific hole radius of {joint_radius}, length of {length}, and height of {height} dimensions are up to your creative interpretation.",
    "Can you design a mechanical leaf spring shackle link with a unique shape? Consider the hole radius of {joint_radius}, length of {length}, and height of {height} in bleaf spring shackle linking this concept to life.",
    "Shape a leaf spring shackle link with a specific hole radius of {joint_radius}, length of {length}, and height of {height}, emphasizing an unconventional and eye-catching design.",
    "Explore the contours of a mechanical leaf spring shackle link's shape, consideleaf spring shackle link the hole radius of {joint_radius}, length of {length}, and height of {height} in your creative process.",
    "Craft a symmetrical leaf spring shackle link with a focus on shape. Share your thoughts on the hole radius of {joint_radius}, length of {length}, and height of {height} for this design.",
    "Design a geometrically inspired leaf spring shackle link, paying attention to the shape. How would you envision the hole radius of {joint_radius}, length of {length}, and height of {height}?",
    "Shape a polished leaf spring shackle link with distinctive contours. Your insights on the hole radius of {joint_radius}, length of {length}, and height of {height} will shape its elegance.",
    "Create a streamlined leaf spring shackle link with a unique shape. Consider the hole radius of {joint_radius}, length of {length}, and height of {height} for a sleek and modern appearance.",
    "Craft a balanced leaf spring shackle link with a distinctive shape. Your creative input on the hole radius of {joint_radius}, length of {length}, and height of {height} will define its character.",
    "Design a customizable leaf spring shackle link with emphasis on shape. How would you approach the hole radius of {joint_radius}, length of {length}, and height of {height} for personalized style?",
    "Shape a leaf spring shackle link with specific values in mind: hole radius of {joint_radius}, length of {length}, and height of {height}. Your artistic vision will guide this project.",
    "Hi, please design a unique model for a leaf spring shackle link with hole radius of {joint_radius}, length of {length}, and height of {height}.",
    "Hi there! Could you create a stunning leaf spring shackle link model with hole radius {joint_radius}, length {length}, and height of {height}?",
    "Hello! I'd love a customized leaf spring shackle link model. Could you work on the hole radius {joint_radius}, length {length}, and height of {height} dimensions?",
    "Hi! Seeking a personalized touch. Please craft a leaf spring shackle link model with specified hole radius of {joint_radius}, length of {length}, and height of {height} values.",
    "Hello, please design a leaf spring shackle link model with a focus on hole radius {joint_radius}, length {length}, and height of {height} dimensions.",
    "Hi! Looking for a special leaf spring shackle link model. Could you consider the hole radius {joint_radius}, length {length}, and height of {height} in your design?",
    "Hello, could you create a model for a leaf spring shackle link? I'm interested in the hole radius {joint_radius}, length {length}, and height of {height} specifics.",
    "Hi there! Seeking a unique leaf spring shackle link model. Please incorporate specified hole radius of {joint_radius}, length of {length}, and height of {height} dimensions.",
    "Hello! I'm in need of a leaf spring shackle link model. Can you please include hole radius {joint_radius} , length {length}, and height of {height} details in your design?",
    "Hi, please craft a leaf spring shackle link model with attention to hole radius {joint_radius}, length {length} , and height of {height} parameters."
]
link_design_strings += [
    "Hey there! Could you create a super cute leaf spring shackle link model for me? Let's go with hole radius {joint_radius}, length {length}, and height of {height} dimensions!",
    "Hi! I'm on a quest for the most adorable leaf spring shackle link model. Can you bleaf spring shackle link some cuteness to life with hole radius {joint_radius}, length {length}, and height of {height} details?",
    "Hey! I'm dreaming of a cute leaf spring shackle link model. Any chance you could sprinkle some charm using hole radius {joint_radius}, length  {length}, and height of {height} measurements?",
    "Hello! Looking for a leaf spring shackle link that's as cute as a button. Mind designing one with hole radius {joint_radius}, length {length} , and height of {height} dimensions?",
    "Hiya! Ready for a cute leaf spring shackle link adventure? Let's dive in with hole radius {joint_radius}, length{length}, and height of {height} specs for an extra dose of adorableness!",
    "Hey friend! Let's create a leaf spring shackle link that's cuteness overload. Can you sketch one up with hole radius {joint_radius}, length {length} , and height of {height} details?",
    "Greetings! In pursuit of perfection, could you meticulously craft a flawless leaf spring shackle link model? I'm keen on hole radius {joint_radius}, length {length}, and height of {height} dimensions.",
    "Hello there! Seeking your expert touch to create a leaf spring shackle link model of sheer perfection. hole radius {joint_radius}, length {length}, and height of {height} details will make it impeccable.",
    "Good day! With an eye for perfection, could you design an impeccable leaf spring shackle link model? Paying close attention to hole radius {joint_radius}, length {length}, and height of {height} dimensions.",
    "Salutations! I'm on a quest for perfection in a leaf spring shackle link model. Your precision with hole radius {joint_radius}, length {length}, and height of {height} details would be truly appreciated.",
    "Hi! In the pursuit of perfection, I'd be delighted if you could fashion a leaf spring shackle link model with exquisite hole radius {joint_radius}, length {length}, and height of {height} specifications.",
    "Greetings! As we strive for perfection, could you please create an impeccable leaf spring shackle link model? The specifics I'm looking for include hole radius {joint_radius}, length {length}, and height of {height}.",
    "Hello! With perfection in mind, I'd love your expertise in crafting a flawless leaf spring shackle link model. hole radius {joint_radius} , length {length}, and height of {height} dimensions are key.",
    "Good day! Seeking the touch of perfection for a leaf spring shackle link model. Your attention to hole radius {joint_radius} , length {length}, and height of {height} details will undoubtedly elevate its beauty.",
    "Salutations! In the pursuit of perfection, your design prowess would be greatly valued for a leaf spring shackle link model. hole radius {joint_radius}, length {length} , and height of {height} precision, please.",
    "Hi there! With an emphasis on perfection, could you lend your skills to create a flawless leaf spring shackle link model? The hole radius {joint_radius}, length {length}, and height of {height} dimensions are key.",
    "I need a leaf spring shackle link model with precise hole radius  {joint_radius} , length {length}, and height of {height} dimensions. No room for error, please.",
    "Craft a leaf spring shackle link model with exact hole radius  {joint_radius} , length {length} , and height of {height} specifications. I expect accuracy.",
    "Design a flawless leaf spring shackle link model. Outer radius  {joint_radius}, length {length}, and height of {height} details should be spot-on.",
    "I require a leaf spring shackle link model designed with absolute precision. Provide exact   hole radius {joint_radius} , length {length} , and height of {height} measurements.",
    "No compromises. Design a leaf spring shackle link model with meticulous attention to radiuses of  hole radius {joint_radius} , length {length}, and height of {height} dimensions.",
    "Precision is key. Create a leaf spring shackle link model ensuleaf spring shackle link perfection in hole radius {joint_radius}, length {length}, and height of {height} specifications.",
    "Ensure perfection. Design a leaf spring shackle link model with meticulous precision in hole radius {joint_radius}, length {length}, and height of {height} dimensions.",
    "I don't want errors. Create a leaf spring shackle link model with precise hole radius {joint_radius}, length {length}, and height of {height} details.",
    "No room for mistakes. Provide a leaf spring shackle link model with exact hole radius {joint_radius}, length {length}, and height of {height} specifications.",
    "Perfection is the standard. Craft a leaf spring shackle link model with flawless hole radius {joint_radius}, length {length}, and height of {height} dimensions.",
    "Demanding precision. I need a leaf spring shackle link model with spot-on hole radius {joint_radius}, length {length}, and height of {height} measurements.",
    "No compromises on precision. Deliver a leaf spring shackle link model with exact hole radius {joint_radius}, length {length}, and height of {height} details.",
    "Attention to detail is a must. Provide a leaf spring shackle link model with impeccable hole radius {joint_radius}, length {length}, and height of {height} specifications.",
    "I expect perfection. Design a leaf spring shackle link model with flawless hole radius {joint_radius} , length {length}, and height of {height} dimensions.",
    "Precise craftsmanship required. Deliver a leaf spring shackle link model with exact hole radius {joint_radius} , length {length}, and height of {height} measurements.",
    "Strict requirements: Create a leaf spring shackle link model with precision in hole radius {joint_radius}, length {length}, and height of {height} details.",
    "Kindly design a leaf spring shackle link model adheleaf spring shackle link strictly to the specified hole radius {joint_radius} , length {length}, and height of {height} dimensions.",
    "I require a leaf spring shackle link model crafted with utmost precision. Please ensure strict adherence to hole radius{joint_radius} , length {length}, and height of {height} specifications.",
    "Your task is to create a leaf spring shackle link model with strict attention to detail, following precise hole radius {joint_radius}  , length {length} , and height of {height} dimensions.",
    "Craft a leaf spring shackle link model with strict conformity to the specified hole radius = {joint_radius} , length = {length} , and height of {height} measurements. Precision is non-negotiable.",
    "I expect a leaf spring shackle link model that strictly adheres to the provided hole radius = {joint_radius} , length = {length} , and height of {height} parameters. No deviations, please."
]
link_design_strings += [
    "In strict accordance with guidelines, produce a leaf spring shackle link model with precise hole radius = {joint_radius} , length {length}, and height of {height} specifications.",
    "Create a leaf spring shackle link model with strict attention to detail, ensuleaf spring shackle link exact adherence to hole radius {joint_radius} , length {length} , and height of {height} dimensions.",
    "Your assignment is to design a leaf spring shackle link model with strict conformity to the provided hole radius {joint_radius} , length {length} , and height of {height} values. Precision is imperative.",
    "I demand a leaf spring shackle link model with strict precision in hole radius of {joint_radius}, length of {length}, and height of {height} dimensions. Any deviations will not be tolerated.",
    "Kindly ensure strict compliance with the hole radius of {joint_radius}, length of {length}, and height of {height} specifications when crafting the leaf spring shackle link model.",
    "Design a leaf spring shackle link model with meticulous attention to the specified height of {height}, hole radius of {joint_radius}, and length of {length} dimensions.",
    "For this project, I need a leaf spring shackle link model crafted with precision, emphasizing the exact height of {height}, hole radius of {joint_radius}, and length of {length} specifications.",
    "Your expertise is required to create a flawless leaf spring shackle link model, with particular emphasis on the specified height of {height}, hole radius of {joint_radius}, and length of {length} dimensions.",
    "Craft a leaf spring shackle link model with strict conformity to the provided height of {height}, hole radius of {joint_radius}, and length of {length} measurements. Precision in height is critical.",
    "In this assignment, prioritize the design around the specified height of {height}, hole radius of {joint_radius}, and length of {length} parameters for an impeccable leaf spring shackle link model.",
    "I insist on a leaf spring shackle link model that strictly adheres to the provided height of {height}, hole radius of {joint_radius}, and length of {length} parameters. Height precision is non-negotiable.",
    "Create a leaf spring shackle link model with an unwaveleaf spring shackle link focus on the specified height of {height}, hole radius of {joint_radius}, and length of {length} dimensions. Strict adherence to guidelines is expected.",
    "For this project, your task is to design a leaf spring shackle link model with a strict emphasis on the provided height of {height}, hole radius of {joint_radius}, and length of {length} guidelines.",
    "I require a leaf spring shackle link model that prioritizes strict precision in height of {height}, hole radius of {joint_radius}, and length of {length} dimensions. Any deviations will not be tolerated.",
    "Kindly ensure strict compliance with the height of {height}, hole radius of {joint_radius}, and length of {length} specifications when crafting the leaf spring shackle link model for this project.",
    "Your responsibility is to create a leaf spring shackle link model where the emphasis lies on strict adherence to the provided height of {height}, hole radius of {joint_radius}, and length of {length} values.",
    "Craft a leaf spring shackle link model with meticulous attention to the specified height of {height}, ensuleaf spring shackle link exact adherence to the provided hole radius of {joint_radius} and length of {length} dimensions. Precision is non-negotiable.",
    "In this project, I expect a leaf spring shackle link model that strictly follows the provided height of {height}, hole radius of {joint_radius}, and length of {length} parameters. Height precision is of the utmost importance.",
    "Your task is to design a leaf spring shackle link model with a strict focus on height precision of {height}, adheleaf spring shackle link to the provided hole radius of {joint_radius} and length of {length} dimensions.",
    "Create a leaf spring shackle link model with strict conformity to the specified height of {height}, hole radius of {joint_radius}, and length of {length} values. Deviations in height will not be accepted.",
    "For this assignment, your task is to design a leaf spring shackle link model with strict precision in height of {height}, hole radius of {joint_radius}, and length of {length} dimensions. Adherence to guidelines is expected.",
    "I demand a leaf spring shackle link model that strictly adheres to the provided height of {height}, hole radius of {joint_radius}, and length of {length} specifications. Height precision is mandatory.",
    "In strict accordance with the outlined requirements, produce a leaf spring shackle link model with precise height of {height}, hole radius of {joint_radius}, and length of {length} dimensions.",
    "Craft a leaf spring shackle link model with meticulous attention to height {height} , ensuleaf spring shackle link exact adherence to the specified hole radius of {joint_radius} and length of {length} dimensions. Precision is non-negotiable.",
    "Your assignment is to create a leaf spring shackle link model with strict conformity to the provided height of {height}, hole radius of {joint_radius}, and length of {length} values. Height precision is required.",
    "Design a leaf spring shackle link model, focusing primarily on the specified height of {height}, and then adheleaf spring shackle link to the provided hole radius of {joint_radius} and length of {length} parameters.",
    "For this task, create a leaf spring shackle link model with detailed attention to the specified height of {height}, hole radius of {joint_radius}, and length of {length} parameters.",
    "Your expertise is crucial in crafting a leaf spring shackle link model with a heightened emphasis on the specified height of {height}, hole radius of {joint_radius}, and length of {length} dimensions.",
    "Craft a leaf spring shackle link model with an unwaveleaf spring shackle link focus on the specified height of {height}, ensuleaf spring shackle link precision in the provided hole radius of {joint_radius} and length of {length} measurements.",
    "I insist on a leaf spring shackle link model that strictly adheres to the provided height of {height}, ensuleaf spring shackle link impeccable precision in hole radius of {joint_radius} and length of {length} dimensions.",
    "Create a leaf spring shackle link model where the key emphasis is on the specified height of {height}, followed by precision in the provided hole radius of {joint_radius} and length of {length} parameters.",
    "For this assignment, your task is to design a leaf spring shackle link model with meticulous attention to height precision of {height}, adheleaf spring shackle link to the provided hole radius of {joint_radius} and length of {length} dimensions.",
    "I require a leaf spring shackle link model that prioritizes strict compliance with the specified height of {height}, ensuleaf spring shackle link impeccable precision in hole radius of {joint_radius} and length of {length} measurements.",
    "Craft a leaf spring shackle link model with a heightened focus on the specified height of {height}, ensuleaf spring shackle link strict adherence to the provided hole radius of {joint_radius} and length of {length} dimensions.",
    "Your responsibility is to create a leaf spring shackle link model where the central emphasis lies on strict precision in height of {height}, adheleaf spring shackle link to the provided hole radius of {joint_radius} and length of {length} values."
]

# %% [markdown]
# ## length

# %%
size = len(link_design_strings)
print(size)
# Out:
# 11

# %% [markdown]
# # code

# %% [markdown]
# ## libraries

# %%
import json
import random
import math
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive

from google.colab import files
# Out:
# WARNING:root:pydrive is deprecated and no longer maintained. We recommend that you migrate your projects to pydrive2, the maintained fork of pydrive

# %% [markdown]
# ## Preparing the dataset

# %%
for i in range(len(link_design_strings)):
    # Replace 'diameter' with 'radius' in the current element
    link_design_strings[i] = link_design_strings[i].replace('diameter', 'radius')
    link_design_strings[i] = link_design_strings[i].replace('RAD', 'radius')
    link_design_strings[i] = link_design_strings[i].replace('outer radius', 'hole radius')
    link_design_strings[i] = link_design_strings[i].replace('inner radius', 'length')
    link_design_strings[i] = link_design_strings[i].replace('outer_radius', 'joint_radius')
    link_design_strings[i] = link_design_strings[i].replace('inner_radius', 'length')

# %%
for i in range(len(link_design_strings)):
    if i %2 == 0:
     link_design_strings[i] = link_design_strings[i].replace('hole radius', 'joint radius')

# %%
link_design_strings[0]
# Out:
# 'Design a 3D model for a leaf spring shackle link with an joint radius of {joint_radius}, length of {length}, and a height of {height}.'

# %% [markdown]
# ## itterations

# %%
num_iterations = 1

# %% [markdown]
# ## only radius

# %%
filled_ring_design_strings = []

# %%
with open('/content/drive/MyDrive/project/FunctionCALLfalcondata.json', 'a') as file:
 for design_string in link_design_strings  :
    for i in range (num_iterations):

      joint_radius = round(random.uniform(3, 20), 2)
      arc_radius = joint_radius * 2.6
      link_width = arc_radius * 2
      height = round(random.uniform(3, 20), 2)
      area_circle_small = math.pi * joint_radius**2
      area_circle_large = math.pi * arc_radius**2
      perimeter_circle = 2 * math.pi * arc_radius

      link_length = round(random.uniform(2 * joint_radius + 1, 200), 2)
      area_link=round((link_length*link_width)+area_circle_large-2*area_circle_small,2)
      perimeter_link=round(2* link_length+perimeter_circle,2)

      filled_design_string = design_string.format(height=height,joint_radius= joint_radius ,length= link_length ,joint_diameter = 2* joint_radius   )
      respons = f"Generate_file(shape = 'leaf spring shackle link' , height = {height} , joint_radius= {joint_radius} , length = {link_length} , shackle_area = {area_link} , shackle_perimeter = {perimeter_link})"
      formatted_data = f'{{"text": "### user_promt:{filled_design_string} ### Assistant: {respons}"}}'
      print(formatted_data)

      file.write(formatted_data + '\n')
# Out:
# {"text": "### user_promt:Design a 3D model for a leaf spring shackle link with an joint radius of 7.76, length of 192.09, and a height of 8.33. ### Assistant: Generate_file(shape = 'leaf spring shackle link' , height = 8.33 , joint_radius= 7.76 , length = 192.09 , shackle_area = 8651.71 , shackle_perimeter = 510.95)"}
# {"text": "### user_promt:Seeking a skilled designer to create a 3D printable leaf spring shackle link with an hole radius of 9.48, length of 186.12, and a height of 7.51. ### Assistant: Generate_file(shape = 'leaf spring shackle link' , height = 7.51 , joint_radius= 9.48 , length = 186.12 , shackle_area = 10518.89 , shackle_perimeter = 527.11)"}
# ...

# %% [markdown]
# ## only diameter

# %%
filled_ring_design_strings = []

# %%
with open('/content/drive/MyDrive/project/FunctionCALLfalcondata.json', 'a') as file:
 for design_string in link_design_strings  :
    for i in range (num_iterations):
      design_string = design_string.replace('radius' , 'diameter')
      design_string = design_string.replace('joint_radius' , 'joint_diameter')

      joint_radius = round(random.uniform(3, 20), 2)
      arc_radius = joint_radius * 2.6
      link_width = arc_radius * 2
      height = round(random.uniform(3, 20), 2)
      area_circle_small = math.pi * joint_radius**2
      area_circle_large = math.pi * arc_radius**2
      perimeter_circle = 2 * math.pi * arc_radius

      link_length = round(random.uniform(2 * joint_radius + 1, 200), 2)
      area_link=round((link_length*link_width)+area_circle_large-2*area_circle_small,2)
      perimeter_link=round(2* link_length+perimeter_circle,2)

      filled_design_string = design_string.format(height=height,joint_radius= joint_radius ,length= link_length ,joint_diameter = 2* joint_radius   )
      respons = f"Generate_file(shape = 'leaf spring shackle link' , height = {height} , joint_radius= {joint_radius} , length = {link_length} , shackle_area = {area_link} , shackle_perimeter = {perimeter_link})"
      formatted_data = f'{{"text": "### user_promt:{filled_design_string} ### Assistant: {respons}"}}'
      print(formatted_data)

      file.write(formatted_data + '\n')
# Out:
# {"text": "### user_promt:Design a 3D model for a leaf spring shackle link with an joint diameter of 7.42, length of 86.59, and a height of 12.97. ### Assistant: Generate_file(shape = 'leaf spring shackle link' , height = 12.97 , joint_radius= 3.71 , length = 86.59 , shackle_area = 1876.32 , shackle_perimeter = 233.79)"}
# {"text": "### user_promt:Seeking a skilled designer to create a 3D printable leaf spring shackle link with an hole diameter of 32.16, length of 125.5, and a height of 7.41. ### Assistant: Generate_file(shape = 'leaf spring shackle link' , height = 7.41 , joint_radius= 16.08 , length = 125.5 , shackle_area = 14360.41 , shackle_perimeter = 513.69)"}
# ...
